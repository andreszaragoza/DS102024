# %% [markdown]
# # Ex1 - Obtener y conocer sus datos

# %% [markdown]
# ### Paso 1: Ir a https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ### Paso 2. Descargue el conjunto de datos en su ordenador y descomprímalo.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Paso 3. Utilice el archivo csv y asígnelo a un marco de datos llamado alimentos

# %%
url = "food_100.csv"
alimentos = pd.read_csv(url)
alimentos
# Out:
#     Unnamed: 0   code                                                url  \
# 0            0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1            1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2            2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3            3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4            4  16094  http://world-en.openfoodfacts.org/product/0000...
# ..         ...    ...                                                ...
# 95          95  34715  http://world-en.openfoodfacts.org/product/0000...
# 96          96  34784  http://world-en.openfoodfacts.org/product/0000...
# 97          97  34791  http://world-en.openfoodfacts.org/product/0000...
# 98          98  35071  http://world-en.openfoodfacts.org/product/0000...
# 99          99  35170  http://world-en.openfoodfacts.org/product/0000...
#
#                        creator   created_t      created_datetime  \
# ...

# %% [markdown]
# ### Paso 4. Ver las 5 primeras entradas

# %%
alimentos.head()
# Out:
#    Unnamed: 0   code                                                url  \
# 0           0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1           1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2           2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3           3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4           4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#    last_modified_t last_modified_datetime                    product_name  \
# ...

# %% [markdown]
# ### Paso 5. ¿Cuál es el número de observaciones del conjunto de datos?

# %%
len(alimentos)
# Out:
# 100

# %% [markdown]
# ### Paso 6. ¿Cuál es el número de columnas del conjunto de datos?

# %%
len(alimentos.columns)
# Out:
# 164

# %% [markdown]
# ### Paso 7. Imprime el nombre de todas las columnas.

# %%
print(*alimentos.columns)
# Out:
# Unnamed: 0 code url creator created_t created_datetime last_modified_t last_modified_datetime product_name generic_name quantity packaging packaging_tags brands brands_tags categories categories_tags categories_en origins origins_tags manufacturing_places manufacturing_places_tags labels labels_tags labels_en emb_codes emb_codes_tags first_packaging_code_geo cities cities_tags purchase_places stores countries countries_tags countries_en ingredients_text allergens allergens_en traces traces_tags traces_en serving_size no_nutriments additives_n additives additives_tags additives_en ingredients_from_palm_oil_n ingredients_from_palm_oil ingredients_from_palm_oil_tags ingredients_that_may_be_from_palm_oil_n ingredients_that_may_be_from_palm_oil ingredients_that_may_be_from_palm_oil_tags nutrition_grade_uk nutrition_grade_fr pnns_groups_1 pnns_groups_2 states states_tags states_en main_category main_category_en image_url image_small_url energy_100g energy-from-fat_100g fat_100g saturated-f
# ...

# %% [markdown]
# ### Paso 8. ¿Cómo se llama la columna 105?

# %%
alimentos.columns[104]
# Out:
# '-sucrose_100g'

# %% [markdown]
# ### Paso 9. ¿Cuál es el tipo de las observaciones de la columna 105?

# %%
alimentos.iloc[:, 104].dtype
# Out:
# dtype('float64')

# %%
alimentos.iloc[:, 104].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: -sucrose_100g, dtype: float64

# %% [markdown]
# ### Paso 10. ¿Cómo se indexa el conjunto de datos?

# %%
alimentos.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
alimentos.set_index('product_name')
# Out:
#                                 Unnamed: 0   code  \
# product_name
# Farine de blé noir                       0   3087
# Banana Chips Sweetened (Whole)           1   4530
# Peanuts                                  2   4559
# Organic Salted Nut Mix                   3  16087
# Organic Polenta                          4  16094
# ...                                    ...    ...
# Organic Pecan Halves                    95  34715
# Unsalted Dry Roasted Almonds            96  34784
# Organic Raw Pumpkin Seeds               97  34791
# Organic Extra Virgin Olive Oil          98  35071
# Liquid Aminos                           99  35170
#
#                                                                               url  \
# product_name
# Farine de blé noir              http://world-en.openfoodfacts.org/product/0000...
# Banana Chips Sweetened (Whole)  http://world-en.openfoodfacts.org/product/0000...
# Peanuts                         http://world-en.openfoodfacts.org/product/0000...
# ...

# %% [markdown]
# ### Paso 11. ¿Cuál es el nombre del producto de la 19ª observación?

# %%
alimentos.loc[18, 'product_name']
# Out:
# 'Lotus Organic Brown Jasmine Rice'
