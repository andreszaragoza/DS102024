# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios funciones
# ## Ejercicio 1
# Escribe una función que convierta números del 1 al 7 en nombres de los dias de la semana. La función constará de un único argumento numérico y una salida de tipo string

# %%
def dias_semana(numdia):
    respuesta = ''
    if numdia == 1:
        respuesta = 'lunes'
    elif numdia == 2:
        respuesta = 'martes'
    elif numdia == 3:
        respuesta = 'mmiercoles'
    elif numdia == 4:
        respuesta = 'jueves'
    elif numdia == 5:
        respuesta = 'viernes'
    elif numdia == 6:
        respuesta = 'sabado'
    elif numdia == 7:
        respuesta = 'domingo'
    else:
        respuesta ='No es un dia valido'
    return respuesta

# %%
num_dia = int(input('Ingrese un numero de la semana :'))

# %%
resultado_de_dia = dias_semana(num_dia)

# %%
print(resultado_de_dia)
# Out:
# viernes

# %% [markdown]
# ## Ejercicio 2
# En el ejercicio 8 de bucles, creábamos una pirámide invertida, cuyo número de pisos venía determinado por un input del usuario. Crea una función que replique el comportamiento de la pirámide, y utiliza un único parámetro de entrada de la función para determinar el número de filas de la pirámide, es decir, elimina la sentencia input.

# %%
def piramide_invertida(filas):
    for piso in range(filas, 0, -1):
        print(" " * (filas - piso) + "*" * (2 * piso - 1))

# %%
piramide_invertida(6)
# Out:
# ***********
#  *********
#   *******
#    *****
#     ***
#      *

# %% [markdown]
# ## Ejercicio 3
# Escibe una función que compare dos números. La función tiene dos argumentos y hay tres salidas posibles: que sean iguales, que el primero se  mayor que el segundo, o que el segundo sea mayor que el primero

# %%
num_1 = 3
num_2 = 5

# %%
if num_1 == num_2:
    out = "Son iguales"
elif num_1 > num_2:
    out = "Primer número mayor que el segundo"
else:
    out = "Segundo número mayor que el primero"

# %%
print(out)
# Out:
# Son iguales

# %% [markdown]
# ## Ejercicio 4
# Escribe una función que sea un contador de letras. En el primer argumento tienes que introducir un texto, y el segundo que sea la letra a contar. La función tiene que devolver un entero con el número de veces que aparece esa letra, tanto mayuscula, como minúscula

# %%
def contador_de_letras(texto, letra):
    texto = texto.lower()
    letra= letra.lower()

    contador = 0
    for caracter in texto:
        if caracter == letra:
            contador +=1
    return contador

# %%
resultado = contador_de_letras("Hola Mundo mundial", "a")
print(resultado)
# Out:
# 2

# %% [markdown]
# ## Ejercicio 5
# Escribe una función que tenga un único argumento, un string. La salida de la función tiene que ser un diccionario con el conteo de todas las letras de ese string.

# %%
def elemento(texto):
    conteo = {}

    for cada in texto:
        if cada.isalpha():
            if cada in conteo:
                conteo[cada] +=1
            else:
                conteo[cada] = 1
    return conteo

# %%
resultado1 = elemento("Hola a todos")

# %%
print(resultado1)
# Out:
# {'H': 1, 'o': 3, 'l': 1, 'a': 2, 't': 1, 'd': 1, 's': 1}

# %% [markdown]
# ## Ejercicio 6
# Escribir una función que añada o elimine elementos en una lista. La función necesita los siguientes argumentos:
# * lista: la lista donde se añadirán o eliminarán los elementos
# * comando: "add" o "remove"
# * elemento: Por defecto es None.

# %%
lista_str = input("Introduzca una lista: ")
comando = input("Introduzca un comando (add or remove): ")
elemento = input("Introduzca un elemento: ")

# %%
def ejercicio_6(lista, comando, elemento=None):
    if comando == "add":
        if elemento is not None:
            lista.append(elemento)
        else:
            print("Debes especificar un elemento para agregar.")
    elif comando == "remove":
        if elemento is not None:
            try:
                lista.remove(elemento)
            except ValueError:
                print("El elemento no se encuentra en la lista")
        else:
            print("Debes especificar un elemento para eliminar.")
    else:
        print("Comando no reconocido")
    return lista

# %%
lista = lista_str.split(',')
resultado = ejercicio_6(lista, comando, elemento)
print(resultado)
# Out:
# ['1', '2', '3', '4', 'none']

# %% [markdown]
# ## Ejercicio 7
# Crea una función que reciba un número arbitrario de palabras, y devuelva una frase completa, separando las palabras con espacios.

# %%
def ejercicio_7(*args):
    return " ".join(args)

# %%
ejercicio_7("Que", "tal", "vamos", "por", "alli",)
# Out:
# 'Que tal vamos por alli'

# %% [markdown]
# ## Ejercicio 8
# Escribe un programa que obtenga el enésimo número de la [serie de Fibonacci](https://es.wikipedia.org/wiki/Sucesi%C3%B3n_de_Fibonacci). Tienes que crear una función recursiva con un único argumento.
#
# ```Python
# fibonacci(2) = 1
# fibonacci(4) = 3
# fibonacci(5) = 5
# fibonacci(8) = 21
# ```

# %%
def fibonacci(n):
    if n == 0 or n == 1:
        return n
    return fibonacci(n-1) + fibonacci(n-2)

# %%
fibonacci(20)
# Out:
# 6765

# %% [markdown]
# ## Ejercicio 9
# Define en una única celda las siguientes funciones:
# * Función que calcule el área de un cuadrado
# * Función que calcule el area de un triángulo
# * Función que calcule el área de un círculo
#
# En otra celda, calcular el area de:
# * Dos círculos de radio 10 + un triángulo de base 3 y altura 7
# * Un cuadrado de lado = 10 + 3 círculos (uno de radio = 4 y los otros dos de radio = 6) + 5 triángulos de base = 2 + altura = 4

# %%
import math

math.pi
# Out:
# 3.141592653589793

# %%
def cuadrado(l):
    return l ** 2

def triangulo(b, a):
    return b * a / 2

def circulo(r):
    return math.pi * r ** 2

# %%
print("Area 1:", 2 * circulo(10) + triangulo(3, 7))
# Out:
# Area 1: 638.8185307179587

# %%
print("Area 2:", cuadrado(10) + circulo(4) + 2*circulo(6) + 5*triangulo(2,4))
# Out:
# Area 2: 396.46015351590177
